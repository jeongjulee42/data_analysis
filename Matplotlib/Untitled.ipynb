# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
days = [1,2,3] # 1일, 2일, 3일
az = [2,4,8] # 단위: 만명. 1~3일까지 az 접종 인구
pfizer = [5,1,3]
moderna = [1,2,5]

# %%
plt.plot(days, az)
plt.plot(days,pfizer)
plt.plot(days,moderna)
